# %%
import pandas as pd

# %%
# load Dogecoin data
df_doge = pd.read_pickle('./data/elon_doge.plk')
df_doge
# Out:
#                            Elon Musk's Tweet in List  Dogecoin Price  \
# Time
# 2020-09-13 13:00:00                               []        0.002713
# 2020-12-05 21:00:00                               []        0.003399
# 2020-12-05 21:00:00                               []        0.003399
# 2020-12-05 22:00:00  [@haya2e_jaxa Congratulations!]        0.003432
# 2020-12-05 23:00:00                               []        0.003340
# ...                                              ...             ...
# 2021-02-27 01:00:00                               []        0.051340
# 2021-02-27 02:00:00                               []        0.051060
# 2021-02-27 03:00:00                               []        0.051220
# 2021-02-27 04:00:00                               []        0.051420
# 2021-02-27 05:00:00                               []        0.051260
#
#                        Elon Musk's Tweet in String  \
# Time
# 2020-09-13 13:00:00
# 2020-12-05 21:00:00
# 2020-12-05 21:00:00
# ...

# %%
# Slice signal related columns
signals_df = df_doge[["Dogecoin Price", "Does Elon Musk's Tweet Tention the Word DOGE?"]]
signals_df
# Out:
#                      Dogecoin Price  \
# Time
# 2020-09-13 13:00:00        0.002713
# 2020-12-05 21:00:00        0.003399
# 2020-12-05 21:00:00        0.003399
# 2020-12-05 22:00:00        0.003432
# 2020-12-05 23:00:00        0.003340
# ...                             ...
# 2021-02-27 01:00:00        0.051340
# 2021-02-27 02:00:00        0.051060
# 2021-02-27 03:00:00        0.051220
# 2021-02-27 04:00:00        0.051420
# 2021-02-27 05:00:00        0.051260
#
#                      Does Elon Musk's Tweet Tention the Word DOGE?
# Time
# 2020-09-13 13:00:00                                              0
# 2020-12-05 21:00:00                                              0
# 2020-12-05 21:00:00                                              0
# 2020-12-05 22:00:00                                              0
# 2020-12-05 23:00:00                                              0
# ...                                                            ...
# ...

# %%
# Calculate the points in time at which a position should be taken, 1 for entry, -1 for exit, 0 for no action
signals_df['Entry/Exit'] = signals_df["Does Elon Musk's Tweet Tention the Word DOGE?"]
signals_df
# Out:
# /Users/markyang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      Dogecoin Price  \
# Time
# 2020-09-13 13:00:00        0.002713
# 2020-12-05 21:00:00        0.003399
# 2020-12-05 21:00:00        0.003399
# 2020-12-05 22:00:00        0.003432
# 2020-12-05 23:00:00        0.003340
# ...                             ...
# 2021-02-27 01:00:00        0.051340
# 2021-02-27 02:00:00        0.051060
# 2021-02-27 03:00:00        0.051220
# 2021-02-27 04:00:00        0.051420
# 2021-02-27 05:00:00        0.051260
#
#                      Does Elon Musk's Tweet Tention the Word DOGE?  Entry/Exit
# Time
# ...
