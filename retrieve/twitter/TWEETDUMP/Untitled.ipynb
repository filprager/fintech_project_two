# %%
import pandas as pd
pd.read_pickle("all_elon_musk_twitter_df")
# Out:
#                   created_at                   id  \
# 0   2021-02-20T10:06:29.000Z  1363067491673468932
# 1   2021-02-20T09:16:14.000Z  1363054845976961029
# 2   2021-02-20T08:42:28.000Z  1363046350900785156
# 3   2021-02-20T08:31:11.000Z  1363043511507898368
# 4   2021-02-20T07:02:06.000Z  1363021091086561285
# ..                       ...                  ...
# 95  2021-02-07T02:24:19.000Z  1358240143459577859
# 96  2021-02-06T22:23:23.000Z  1358179508617007104
# 97  2021-02-06T22:17:10.000Z  1358177945739685893
# 98  2021-02-06T22:16:52.000Z  1358177870703517698
# 99  2021-02-06T22:14:57.000Z  1358177385678467072
#
#                                                  text  \
# 0   @PPathole @dogecoin Just some used Antminer L3...
# 1   @WholeMarsBlog Most people have no idea, even ...
# 2   @dogecoin I just set up some little Doge minin...
# 3                                 @redditSpacePorn 🤣🤣
# 4   @PeterSchiff That said, BTC &amp; ETH do seem ...
# ...
