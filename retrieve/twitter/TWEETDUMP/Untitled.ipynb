# %%
import pandas as pd
pd.read_pickle("twitter_elon_all_df")
# Out:
#                                                  text  \
# 0                                      @PeterSchiff 🍆
# 1                                @PPathole Super cool
# 2   @jgrano305 @AustinTeslaClub We have too much p...
# 3               @TechAmazing @UniverCurious Tunnels!!
# 4   @JantieWillie @Adamklotz_ @AustinTeslaClub Hop...
# ..                                                ...
# 2                                      @nichegamer 🤣🤣
# 3                But actually https://t.co/jlowaHobXO
# 4   @arvnp @Jamie_Woodward_ The Standard Model is ...
# 5                            @Jamie_Woodward_ … is bs
# 6                      @Jamie_Woodward_ String theory
#
#                   created_at author_id                   id
# 0   2021-02-23T08:20:41.000Z  44196397  1364128031434887170
# 1   2021-02-23T08:18:12.000Z  44196397  1364127406689193986
# 2   2021-02-22T23:25:09.000Z  44196397  1363993259756945410
# 3   2021-02-22T20:22:10.000Z  44196397  1363947211277496320
# ...
